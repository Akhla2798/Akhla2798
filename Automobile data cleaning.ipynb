# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Extract Automobile data

# %%
mobile = pd.read_csv('Downloads/Automobile price data _Raw_ (1).csv')

# %%
mobile
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %% [markdown]
#  Droping duplicate values

# %%
mobile.drop_duplicates()
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
mobile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
mobile.shape
# Out:
# (205, 26)

# %%
mobile.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size        bore      stroke  compression-ratio  \
# count   205.000000   205.000000  205.000000  205.000000         205.000000
# mean   2555.565854   126.907317    3.330927    3.258049          10.142537
# std     520.680204    41.642693    0.270973    0.314152           3.972040
# ...

# %% [markdown]
#  column - price insteed of '?',replacing some mean values

# %%
mobile.iloc[9,25]=mobile.iloc[9,25].replace('?','17859')
mobile.iloc[44,25]=mobile.iloc[44,25].replace('?','8916')
mobile.iloc[45,25]=mobile.iloc[45,25].replace('?','8916')
mobile.iloc[129,25]=mobile.iloc[129,25].replace('?','31400')

# %%
mobile.head(15)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3                 ?  alfa-romero       gas        std
# 1           3                 ?  alfa-romero       gas        std
# 2           1                 ?  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2               164         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1               158         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0               164         audi       gas      turbo
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
# 12          0               188          bmw       gas        std
# ...

# %% [markdown]
# columns - normalized-losses,horsepower,peak-rpm,insteed of '?',replacing some mean values

# %%
mobile.iloc[:,1]=mobile.iloc[:,1].replace('?', '121')
mobile.iloc[:,21]=mobile.iloc[:,21].replace('?','103')
mobile.iloc[:,22]=mobile.iloc[:,22].replace('?','5075')

# %%
mobile.head(134)
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               121  alfa-romero       gas        std
# 1            3               121  alfa-romero       gas        std
# 2            1               121  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 129          1               186      porsche       gas        std
# 130          0               121      renault       gas        std
# 131          2               121      renault       gas        std
# 132          3               150         saab       gas        std
# 133          2               104         saab       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
import matplotlib.pyplot as plt
from scipy.stats import poisson, expon

# %%
pip install ydata-profiling
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import ydata_profiling as pp

# %%
profile = pp.ProfileReport(mobile)

# %%
profile.to_file('mobile_aug.html')
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# In this page plots are not getting i done at automobile plot page
